# %%
import sys
from datetime import datetime, timedelta
import requests
import fileinput
import os.path
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder

import warnings
warnings.filterwarnings("ignore")

from matplotlib import pyplot
import seaborn as sns

fileFinal  = 'working/final.csv'

df = pd.read_csv(fileFinal,sep=';')
df["data_pesquisa"]= pd.to_datetime(df["data_pesquisa"])

# %%
# 1062569;CERVEJA ANTARTICA Lata
produto = df[(df['id_produto'] == 1062569)]
produto.plot.bar(figsize=(22,8))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 1062569;CERVEJA ANTARTICA Lata
#       2 produto = df[(df['id_produto'] == 1062569)]
# ----> 3 produto.plot.bar(figsize=(22,8))
#
# File e:\Users\paulo\anaconda3\lib\site-packages\pandas\plotting\_core.py:1131, in PlotAccessor.bar(self, x, y, **kwargs)
#    1043 @Appender(
#    1044     """
#    1045     See Also
#    (...)
#    1120 @Appender(_bar_or_line_doc)
#    1121 def bar(self, x=None, y=None, **kwargs):
#    1122     """
#    1123     Vertical bar plot.
#    1124
#    (...)
#    1129     other axis represents a measured value.
#    1130     """
# -> 1131     return self(kind="bar", x=x, y=y, **kwargs)
#
# File e:\Users\paulo\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
# ...

# %%
prod = pd.crosstab(index=[df['data_pesquisa']],columns=[df['produto']],values=df['preco_encontrado'],aggfunc='mean',dropna='False')
for (columnName, columnValue) in prod.iteritems():
    pyplot.figure(figsize=(22,8))
    pyplot.title('Classificação -  '+str(columnName))
    sns.boxplot(x=columnValue)
    pyplot.show()

# %%
prod_class = pd.crosstab(index=[df['data_pesquisa']],columns=df['produto'],values=df['preco_encontrado'],aggfunc='mean',dropna='True')
for (columnName, columnValue) in prod_class.iteritems():
    pyplot.figure(figsize=(22,8))
    pyplot.title('Classificação -  '+columnName)
    prod_class[columnName].plot()
    pyplot.show()
